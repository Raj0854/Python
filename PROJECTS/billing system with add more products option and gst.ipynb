# %%
#billing system with add more products option and gst
product = []
price = []
i = input(f'Enter product 1 :-')
product.append(i)
for i in range(100):
    select = input('Do You Want To Add More [y/n]')
    if select == "Y" or select =="y":
        i = input(f'Enter product {i+2} :-')
        product.append(i)
    elif select == "N" or select == "n":
        break
size = len(product)
for i in range(size):
    i = int(input(f'Enter {product[i]} price =>'))
    price.append(i)
yes=input("Do you want add gst?[y/n]")
if yes == "y" or yes=="Y":
    gst=int(input("Ente the Gst %"))
    print('-----------INVOICE BILL------------')
    total=0
    for i in range(size):
        print((i+1),".",product[i],"=>",price[i],"/-")
        total=total+price[i]
        gst_amt=total*gst/100
    print("--------------------------------")
    print('Amount before GST =>',total)
    print("--------------------------------")
    print("GST %","=>",gst,"%")
    print("GST amount","=>",gst_amt,"/-")
    print("--------------------------------")
    print('Total Amount [Inclusive GST] =>',total+gst_amt,"/-")
else:
    print('-----------INVOICE BILL------------')
    total=0
    for i in range(size):
        total= total+price[i]
        print((i+1),".",product[i],"=>",price[i],"/-")
    print("--------------------------------")    
    print('Total Amount [Exclusive GST] =>',total,"/-")
# Out:
# -----------INVOICE BILL------------
# 1 . samosa => 50 /-
# 2 . jalebi => 90 /-
# 3 . apple => 180 /-
# --------------------------------
# Amount before GST => 320
# --------------------------------
# GST % => 18 %
# GST amount => 57.6 /-
# --------------------------------
# Total Amount [Inclusive GST] => 377.6 /-
