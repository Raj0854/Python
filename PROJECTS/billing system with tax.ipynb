# %%
##### billing system with tax
product=[]
price=[]
size = int(input("Enter the product size"))
for i in range (size):
    i=input("Enter the product name:")
    product.append(i)
for i in range(size):
    i =int(input("Enter the product price:-"))
    price.append(i)
print("------------------------------------------")
yes=input("Do you want to add GST[Y/N]")
if yes=="y" or yes=="Y":
    GST=int(input("Enter the GST%"))
    total=0
    for i in range(size):
        total=total+price[i]
        print(i+1,".",product[i],"=>",price[i],"/-")
        gst_amount=total*GST/100
        Total=total+gst_amount
    print("----------------------------")
    print("Total amount:-",total,"/-")
    print("----------------------------")
    print("GST:",GST,"%")
    print("GST amount:-",gst_amount,"/-")
    print("----------------------------")
    print("Final Total [Inclusive GST] :",Total,"/-")
else:
    total=0
    for i in range (size):
        total=total+price[i]
        print((i+1),".",product[i],"=>",price[i],"/")
    print("----------------------------")
    print("Total amount(Without GST):",total,"/-")
    print("----------------------------")
# Out:
# ------------------------------------------
# 1 . samosa => 180 /-
# 2 . jalebi => 52 /-
# 3 . salad => 90 /-
# ----------------------------
# Total amount:- 322 /-
# ----------------------------
# GST: 18 %
# GST amount:- 57.96 /-
# ----------------------------
# Final Total [Inclusive GST] : 379.96 /-
