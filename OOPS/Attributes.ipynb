# %%
#class attributes and object or intances attributes
class bank:
    def account(self):
        print("Bank Name => SBI")
    def amount(self,amount):
        self.amount=amount
        print ("account balance=>",amount)
    def update(self,update):
        print("amount:-",update)
        updated= self.amount+update
        print("new balance:-",updated)
        self.amount=updated

# %%
b=bank()

# %%
b.account()
b.amount(12000)
b.update(10000)
# Out:
# Bank Name => SBI
# account balance=> 12000
# amount:- 10000
# new balance:- 22000
