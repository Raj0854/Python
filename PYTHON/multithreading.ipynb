# %%
from threading import Thread  
import time # import time module 

class data1(Thread):
  def run(self):
    for i in range(10):
      print(i,'----thread 1--------')
      time.sleep(1)

class data2(Thread):
  def run(self):
    for i in range(10):
      print(i,'*****Thread 2*********')
      time.sleep(2)

obj0 = data1()
obj1 = data2()
obj0.start()
obj1.start()
# Out:
# 0 ----thread 1--------
# 0 *****Thread 2*********
# 1 ----thread 1--------
# 1 *****Thread 2*********
# 2 ----thread 1--------
# 3 ----thread 1--------
# 2 *****Thread 2*********
# 4 ----thread 1--------
# 5 ----thread 1--------
# 3 *****Thread 2*********
# 6 ----thread 1--------
# 7 ----thread 1--------
# 4 *****Thread 2*********
# 8 ----thread 1--------
# 9 ----thread 1--------
# 5 *****Thread 2*********
# 6 *****Thread 2*********
# 7 *****Thread 2*********
# 8 *****Thread 2*********
# 9 *****Thread 2*********
