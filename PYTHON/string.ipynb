# %%
msg="welcome. to the world of coding"

# %%
print(msg)
# Out:
# welcome to the world of coding

# %%
print(msg[0:9])
# Out:
# welcome t

# %%
print(msg.upper())
# Out:
# WELCOME TO THE WORLD OF CODING

# %%
print(msg.lower())
# Out:
# welcome to the world of coding

# %%
print(msg.partition('-'))
# Out:
# ('welcome to the world of coding', '', '')

# %%
print(msg.replace("world","duniya"))
# Out:
# welcome to the duniya of coding

# %%
print(msg.find("to"))
# Out:
# 8

# %%
print(msg.index("o"))
# Out:
# 4

# %%
data="p4n.in"
print(data.rstrip(),"this is website-")
# Out:
# p4n.in this is website-

# %%
print(msg.rstrip(),"and is irritate")
# Out:
# welcome to the world of coding and is irritate

# %%
print(msg.isnumeric())
# Out:
# False

# %%
print(msg.startswith('w'))
# Out:
# True

# %%
# Assignment 12: Strings
# String Concatenation:

# Create two strings containing your first and last names.
# Write a function named full_name that takes two strings as parameters and returns the full name.
# Call the function with your strings and print the result

# %%
first="ashwin"
last="kannaujiya"
def full_name():
    return first + last
    # print(first,"",last)
full_name()
# Out:
# 'ashwinkannaujiya'

# %%
# String Length:

# Create a string containing a sentence.
# Write a function named sentence_length that takes a string as a parameter and returns the length of the sentence.
# Call the function with your string and print the result.
sent=(" This is a sentence.")
def sentence_length(a):
    return len(a)
print("the length of data is : ",sentence_length(sent))
# Out:
# the length of data is :  20

# %%
#

# %%
# Substring Search:

# Create a string containing a paragraph.
# Write a function named search_substring that takes a string and a substring as parameters and checks if the substring is present in the string.
# Call the function with your string and a few substrings
par=("Write a function named sentence_length that takes a string as a parameter and returns the length of the sentence.")
def search_substring(a,b):
    return b in a
search_substring(par,"takes")
# Out:
# True
