# %%
data={1,1,131,3,3,3,3,3,3,3,3,3,3,56,463,45,4,541,51,4,21,56,41,4,4,69}

# %%
print(data)
# Out:
# {1, 3, 131, 4, 69, 41, 45, 463, 51, 21, 56, 541}

# %%
data=set(data)
print(data)
# Out:
# {1, 3, 131, 4, 69, 41, 45, 463, 51, 21, 56, 541}

# %%
list_data={1,1,1,2,2,3,4,5,6,7,8,9,1,1,1,1}
set_data=set(list_data)
print(set_data)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}

# %%
data={1,2,3,4,5,6,7,8,9}
data.update([999,998,997,996])

# %%
print(data)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9, 999, 998, 997, 996}

# %%
data="123456789"
data_set=set(data)
print(data_set)
# Out:
# {'3', '4', '1', '7', '8', '2', '9', '6', '5'}

# %%
a=(10+25*2-3+6)
print(type(a))
# Out:
# <class 'int'>

# %%
# Custom function to convert a string representation of a list to an actual list
def string_to_list(string_value):
    # Remove the brackets and split the string by commas
    string_value = string_value.strip("[]")
    list_value = string_value.split(",")
   

# Example usage
string_value = "[1, 2, 3, 4]"
list_value = string_to_list(string_value)
print(list_value)  # Output: [1, 2, 3, 4]
print(type(list_value))  # Output: <class 'list'>
# Out:
# None
# <class 'NoneType'>

# %%
# Set Operations:

# Create two sets of your favorite fruits.
# Write a function named print_unique_fruits that takes two sets as parameters and prints the unique fruits present in both sets.
# Call the function with your sets.
a= {"apple","banana","grape",}
b={"cherry","watermelon","apple"}
def unique(a,b):
    return a - b
unique(a,b)
# Out:
# {'banana', 'grape'}

# %%
# Assignment 11: Dictionaries
# Dictionary Operations:

# Create a dictionary of your favorite movies with movie names as keys and release years as values.
# Write a function named print_movies that takes a dictionary as a parameter and prints each movie along with its release year.
# Call the function with your dictionary
movies={"salaar":"2025","pathan":"2024"}
def print_movies(a):
    for movie,year in movies.items():
        print(f'{movie} : {year}')

print_movies(movies)
# Out:
# salaar : 2025
# pathan : 2024

# %%
# Dictionary Manipulation:

# Create a dictionary of cities and their populations.
# Write a function named calculate_total_population that takes a dictionary as a parameter and returns the total population.
# Call the function with your dictionary and print the result
cities={"mumbai":151000,"pune":85000}
def calculate_total_population(a):
    total_population = sum(a.values())
    return total_population
    
print(calculate_total_population(cities))
# Out:
# 236000
