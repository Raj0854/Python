# %%
A= "AFTAB "
J= "JAMAL "
S= "SHAH."
print(F"YOUR FULL NAME {A+J+S}")
# Out:
# YOUR FULL NAME AFTAB JAMAL SHAH.

# %%
num = int(input("enter a number to get cube.."))
print("Your entered number is : ",num)
print("Your cube number is : ",num**3)
# Out:
# Your entered number is :  85
# Your cube number is :  614125

# %%
def is_even(n):
    if n%2==0:
        return True
    return False
